# %% [markdown]
# # Reading and writing scene with PlantGL

# %%
from oawidgets.plantgl import PlantGL
from openalea.scenemanagement.scene import Scene, CaribuModel

# %% [markdown]
# # Loading and displaying a scene
# The scenes are described in the [TemplateScene](https://github.com/LightModelIntercomparisonOnPlant/TemplateScene) repo.

# %%
sc = Scene('./scene.json')
sc.display()
# Out:
# Plot(antialias=3, axes=['x', 'y', 'z'], axes_helper=1.0, axes_helper_colors=[16711680, 65280, 255], background…

# %% [markdown]
# # Saving scene
# To save the geometry of the scene use the `save` method.

# %%
sc.save("scene_saved.glb")

# %% [markdown]
# If you want to check, you can load it again like so:

# %%
from openalea.scenemanagement.scene import to_pgl
saved_scene = to_pgl("scene_saved.glb")

PlantGL(saved_scene)
# Out:
# Plot(antialias=3, axes=['x', 'y', 'z'], axes_helper=1.0, axes_helper_colors=[16711680, 65280, 255], background…

# %% [markdown]
# # Running caribu with the Scene object
# To run caribu on the scene, first add the caribu model, then run it.

# %%
model = CaribuModel()
sc.add_model(model)
sc.run()

# %% [markdown]
# # Display results
# To display the results of each model, use their `display` method.

# %%
model.display()
# Out:
# Plot(antialias=3, axes=['x', 'y', 'z'], axes_helper=1.0, axes_helper_colors=[16711680, 65280, 255], background…
